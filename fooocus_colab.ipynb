# %%
# !pip uninstall -y cupy cupy-cuda11x cupy-cuda12x
# !pip install --force-reinstall "numpy==1.26.4" \
  "fastapi==0.103.1" "starlette==0.27.0" "pydantic==1.10.15"
# Out:
# WARNING: Skipping cupy as it is not installed.
# WARNING: Skipping cupy-cuda11x as it is not installed.
# WARNING: Skipping cupy-cuda12x as it is not installed.
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting fastapi==0.103.1
#   Using cached fastapi-0.103.1-py3-none-any.whl.metadata (24 kB)
# Collecting starlette==0.27.0
#   Using cached starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting pydantic==1.10.15
#   Downloading pydantic-1.10.15-py3-none-any.whl.metadata (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 14.1 MB/s eta 0:00:00
# Collecting anyio<4.0.0,>=3.7.1 (from fastapi==0.103.1)
#   Using cached anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting typing-extensions>=4.5.0 (from fastapi==0.103.1)
#   Using cached typing_extensions-4.16.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting idna>=2.8 (from anyio<4.0.0,>=3.7.1->fastapi==0.103.1)
#   Using cached idna-3.19-py3-none-any.whl.metadata (9.2 kB)
# Collecting sniffio>=1.1 (from anyio<4.0.0,>=3.7.1->fastapi==0.103.1)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Using cached fastapi-0.103.1-py3-none-any.whl (66 kB)
# Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Downloading pydantic-1.10.15-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 16.0 MB/s eta 0:00:00
# Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Using cached typing_extensions-4.16.0-py3-none-any.whl (45 kB)
# Using cached idna-3.19-py3-none-any.whl (68 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-extensions, sniffio, numpy, idna, pydantic, anyio, starlette, fastapi
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.16.0
#     Uninstalling typing_extensions-4.16.0:
#       Successfully uninstalled typing_extensions-4.16.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: idna
#     Found existing installation: idna 3.19
#     Uninstalling idna-3.19:
#       Successfully uninstalled idna-3.19
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.13.4
#     Uninstalling pydantic-2.13.4:
#       Successfully uninstalled pydantic-2.13.4
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.27.0
#     Uninstalling starlette-0.27.0:
#       Successfully uninstalled starlette-0.27.0
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.103.1
#     Uninstalling fastapi-0.103.1:
#       Successfully uninstalled fastapi-0.103.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cudf-cu12 26.2.1 requires cupy-cuda12x>=13.6.0, which is not installed.
# nx-cugraph-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, which is not installed.
# pylibcugraph-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, which is not installed.
# cudf-cu12 26.2.1 requires cupy-cuda12x>=13.6.0, which is not installed.
# cuml-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, which is not installed.
# cucim-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, which is not installed.
# xarray-einstats 0.11.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# langchain-core 1.5.5 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.15 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# hf-gradio 0.4.1 requires gradio-client<3.0,>=2.0, but you have gradio-client 0.5.0 which is incompatible.
# diffusers 0.39.0 requires safetensors>=0.8.0, but you have safetensors 0.4.3 which is incompatible.
# firebase-admin 6.9.0 requires httpx[http2]==0.28.1, but you have httpx 0.27.0 which is incompatible.
# db-dtypes 1.7.1 requires packaging>=24.2.0, but you have packaging 24.1 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 11.0.3 which is incompatible.
# rasterio 1.5.1 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# wandb 0.28.2 requires pydantic<3,>=2.6, but you have pydantic 1.10.15 which is incompatible.
# google-genai 2.12.1 requires anyio<5.0.0,>=4.8.0, but you have anyio 3.7.1 which is incompatible.
# google-genai 2.12.1 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.0 which is incompatible.
# google-genai 2.12.1 requires pydantic<3.0.0,>=2.12.5, but you have pydantic 1.10.15 which is incompatible.
# google-genai 2.12.1 requires websockets<17.0,>=13.0.0, but you have websockets 11.0.3 which is incompatible.
# langsmith 0.11.0 requires pydantic<3,>=2, but you have pydantic 1.10.15 which is incompatible.
# langsmith 0.11.0 requires websockets>=15.0, but you have websockets 11.0.3 which is incompatible.
# bigquery-magics 0.14.0 requires packaging>=24.2.0, but you have packaging 24.1 which is incompatible.
# ml-dtypes 0.6.0 requires numpy>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# google-cloud-bigquery 3.43.0 requires packaging>=24.2.0, but you have packaging 24.1 which is incompatible.
# opencv-contrib-python 4.14.0.94 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# langgraph-sdk 0.4.2 requires websockets<16,>=14, but you have websockets 11.0.3 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.13 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.15 which is incompatible.
# dataproc-spark-connect 1.1.0 requires tqdm>=4.67, but you have tqdm 4.66.4 which is incompatible.
# dataproc-spark-connect 1.1.0 requires websockets>=14.0, but you have websockets 11.0.3 which is incompatible.
# python-fasthtml 0.14.11 requires starlette>=1.0.1, but you have starlette 0.27.0 which is incompatible.
# langchain 1.3.15 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.15 which is incompatible.
# httpx2 2.10.0 requires anyio>=4.10; sys_platform != "emscripten", but you have anyio 3.7.1 which is incompatible.
# pyiceberg 0.11.1 requires pydantic!=2.12.0,!=2.12.1,!=2.4.0,!=2.4.1,<3.0,>=2.0, but you have pydantic 1.10.15 which is incompatible.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# spacy 3.8.15 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.15 which is incompatible.
# albumentations 2.0.8 requires pydantic>=2.9.2, but you have pydantic 1.10.15 which is incompatible.
# google-adk 2.7.0 requires fastapi<1,>=0.133, but you have fastapi 0.103.1 which is incompatible.
# google-adk 2.7.0 requires pydantic<3,>=2.12, but you have pydantic 1.10.15 which is incompatible.
# google-adk 2.7.0 requires pyyaml<7,>=6.0.2, but you have pyyaml 6.0.1 which is incompatible.
# google-adk 2.7.0 requires starlette<2,>=1.3.1, but you have starlette 0.27.0 which is incompatible.
# google-adk 2.7.0 requires websockets<16,>=15.0.1, but you have websockets 11.0.3 which is incompatible.
# langgraph 1.2.11 requires pydantic>=2.7.4, but you have pydantic 1.10.15 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires tqdm>=4.67, but you have tqdm 4.66.4 which is incompatible.
# weasel 1.0.0 requires pydantic>=2.0.0, but you have pydantic 1.10.15 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.14.0 which is incompatible.
# Successfully installed anyio-3.7.1 fastapi-0.103.1 idna-3.19 numpy-1.26.4 pydantic-1.10.15 sniffio-1.3.1 starlette-0.27.0 typing-extensions-4.16.0

# %%
import numpy
print("NumPy:", numpy.__version__)

try:
    import cupy
    print("CuPy עדיין מותקן:", cupy.__version__)
except ImportError:
    print("CuPy הוסר בהצלחה")
# Out:
# NumPy: 1.26.4
# CuPy הוסר בהצלחה

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# Out:
# Requirement already satisfied: pygit2==1.15.1 in /usr/local/lib/python3.12/dist-packages (1.15.1)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pygit2==1.15.1) (2.1.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (3.0)
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 14913 MB, total RAM 12976 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2274: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'grant_type' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 152, in <module>
#     from webui import *
#   File "/content/Fooocus/webui.py", line 153, in <module>
#     shared.gradio_root = gr.Blocks(title=title).queue()
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 867, in wrapper
#     return queue(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1685, in queue
#     self.app = routes.App.create_app(self)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/routes.py", line 220, in create_app
#     @app.post("/login/")
#      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 704, in decorator
#     self.add_api_route(
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 643, in add_api_route
#     route = route_class(
#             ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 489, in __init__
#     self.dependant = get_dependant(path=self.path_format, call=self.endpoint)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/dependencies/utils.py", line 268, in get_dependant
#     sub_dependant = get_param_sub_dependant(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/dependencies/utils.py", line 111, in get_param_sub_dependant
#     return get_sub_dependant(
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/dependencies/utils.py", line 147, in get_sub_dependant
#     sub_dependant = get_dependant(
#                     ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/dependencies/utils.py", line 289, in get_dependant
#     add_param_to_fields(field=param_field, dependant=dependant)
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/dependencies/utils.py", line 462, in add_param_to_fields
#     if field_info.in_ == params.ParamTypes.path:
#        ^^^^^^^^^^^^^^
# AttributeError: 'FieldInfo' object has no attribute 'in_'
# model_type EPS
# UNet ADM Dimension 2816
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# terminate called without an active exception

# %%
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 14913 MB, total RAM 12976 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# Running on local URL:  http://127.0.0.1:7865
# model_type EPS
# UNet ADM Dimension 2816
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://df2a171a1463b080f4.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.70 seconds
# 2026-08-20 11:49:43.468820: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 10084
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://df2a171a1463b080f4.gradio.live

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
